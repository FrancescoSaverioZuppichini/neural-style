# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

from torchvision.models import vgg19, vgg16
from PIL import Image
from torchvision.transforms import Compose, ToTensor, Resize, Normalize

# %%
def imshow(im):
  plt.figure()
  plt.imshow(im)
  plt.show()

def im_convert(tensor):
    image = tensor.to("cpu").clone().detach()
    image = image.numpy().squeeze()
    image = image.transpose(1, 2, 0)
    image = image * np.array((0.229, 0.224, 0.225)) + np.array(
        (0.485, 0.456, 0.406))
    image = image.clip(0, 1)

    return image

# %%
style = Image.open('./images/picasso.jpg')
content = Image.open('./images/dancing.jpg')

# %%
imshow(style)
imshow(content)

# %%
RESIZE = 244
width, height = content.size

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

mean = torch.tensor([0.485, 0.456, 0.406])
std = torch.tensor([0.229, 0.224, 0.225])

# transform = Compose([Resize((RESIZE, RESIZE)), ToTensor()])
transform = Compose([Resize((RESIZE, RESIZE)), ToTensor(), Normalize(mean=mean, std=std)])

def loader(pil_im, transform=transform):
  return transform(pil_im).unsqueeze(0).to(device).float()

# %%
cnn = vgg19(False).features

for param in cnn.parameters():
  param.requires_grad_(False)
# change maxpool to avg poll -> this should yield better results
for i, layer in enumerate(cnn):
  if isinstance(layer, torch.nn.MaxPool2d):
    cnn[i] = torch.nn.AvgPool2d(kernel_size=2, stride=2, padding=0)

cnn = cnn.to(device).eval()

# %%
class ContentLoss(nn.Module):
    def __init__(self, target):
        super().__init__()
        self.target = target.detach()

    def __call__(self, x):
        return F.mse_loss(x, self.target)

class GradMatrix(nn.Module):
    def __init__(self, input):
        super().__init__()
        b, n, h, w = input.size()
        features = input.view(b * n, h * w)  # resise F_XL into \hat F_XL
        G = torch.mm(features, features.t())  # compute the gram product
        # we 'normalize'
        # self.matrix = G.div(b * n * h * w)
        self.matrix = G
    def __call__(self):
        return self.matrix


class StyleLoss(nn.Module):
    def __init__(self, target):
        super().__init__()
        self.grad_target = GradMatrix(target.detach())()

    def __call__(self, x):
        grad_x = GradMatrix(x)()
        b, n, h, w = x.size()
        return F.mse_loss(grad_x, self.grad_target) / (b * n * h * w)

# %%
# content_x = loader(content)
# storage = StoreFeatures(cnn, [cnn[0], cnn[5]])
# storage(content_x)
# storage.clear()
# print(storage._state)

# %%
from functools import partial, reduce
from collections import OrderedDict

class StoreFeatures():
    def __init__(self, module, where2layers):
        self.module = module
        self.where2layers = where2layers
        self.where = list(where2layers.keys())[0]
        self._state = OrderedDict({})
        self.unsubcribe = []
        self.register_forward_hooks()
        
    @property
    def layers(self):
        return reduce(lambda a, b: a + b, self.where2layers.values())
    
    def register_forward_hooks(self):
        for layer in self.layers:
            # create a hash of a layer as an identifier, this is unique
            name = hash(layer)
            self.unsubcribe.append(layer.register_forward_hook(partial(self.hook, name=name)))
            print(f'[INFO] hook registered to {layer}')
        
    def hook(self, m, i, o, name):
#         store only the outputs from the correct layers defined in self.where2layers
        if m in self.where2layers[self.where]: self._state[self.where][name] = o
    
    def clear(self):
        print('[INFO] clear')
        [un.remove() for un in self.unsubcribe]

    def __call__(self, x, where):
        self.where = where
        if self.where not in self._state: self._state[self.where] = {}
        self.module(x)
        return self._state
        
    def __repr__(self):
        return str({k: [{i : e.shape for i, e in v.items()}] for k, v in self._state.items()})    

    def __getitem__(self, key):
        return self._state[key]
    
    def keys(self):
        return self._state.keys()

# %%
storage = StoreFeatures(cnn, {'foo' : [cnn[5]], 'baa' : [cnn[5], cnn[10]]})

storage(torch.rand(1,3,100,100), 'baa')
storage(torch.rand(1,3,100,100), 'foo')

storage.clear()

storage
# Out:
# [INFO] hook registered to Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] clear
# {'baa': [{287393256: torch.Size([1, 128, 50, 50]), 287393074: torch.Size([1, 256, 25, 25])}], 'foo': [{287393256: torch.Size([1, 128, 50, 50])}]}

# %%
from itertools import chain
from collections import defaultdict

dict3 = defaultdict(list)
for k, v in chain(a.items(), b.items()):
    dict3[k].append(v)
    
dict3
# Out:
# defaultdict(list, {1: ['a', 'c', 'c'], 2: ['b'], 3: ['z', 'z']})

# %%
a = { 1 : 'a', 2 : 'b'}
b = { 3: 'z', 1 : 'c'}

for i,j in reduce(a,b):
    print(i, j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-bc454889b22e> in <module>
#       2 b = { 3: 'z', 1 : 'c'}
#       3
# ----> 4 for i,j in reduce(a,b):
#       5     print(i, j)
#
# TypeError: 'dict' object is not callable

# %%
from functools import partial
from collections import OrderedDict

class StyleAndContentLoss(nn.Module):
    def __init__(self, module, content, style, content_layers, style_layers, style_layers_weights=None, content_layers_weights=None):
        super().__init__()
        self.module = module
        self.content, self.style = content, style
        
        self.content_layers = style_layers
        self.content_layers_weights = content_layers_weights
        
        self.style_layers = style_layers
        self.style_layers_weights = style_layers_weights

        self.features =  StoreFeatures(module, {'inputs': content_layers + style_layers,
                                               'contents': content_layers, 
                                                'styles': style_layers })
#       style and content features can be computed only once
        self.features(style, 'styles')
        self.features(content, 'contents')

    def forward(self, x):
        self.features(x, 'inputs')
        return self.compute_loss()
    
    def compute_loss(self):
        content_loss = 0
        style_loss = 0
        
#       compute content loss
        for key in self.features['contents'].keys():
            input_features, content_features = self.features['inputs'][key], self.features['contents'][key]
            loss = ContentLoss(content_features)(input_features)
            content_loss += loss
#         compute style loss
        for i, key in enumerate(self.features['styles'].keys()):
            input_features, content_features = self.features['inputs'][key], self.features['styles'][key]
            loss = StyleLoss(content_features)(input_features)
            loss *= self.style_layers_weights[i]
            style_loss += loss       

        return (content_loss * 1e4) + (style_loss * 1e3)

    def __repr__(self):
        return str({k: [e.shape for e in v] for k, v in self.features.items()})

# %%
cnn = cnn.to(device).eval()

content_layers = [cnn[19]]

style_layers = [cnn[0], cnn[5], cnn[10], cnn[19], cnn[28]]
style_layers_weights = [ 0.75, 0.5, 0.2, 0.2, 0.2]

content_x = loader(content)
style_x = loader(style)
x = torch.randn_like(content_x).requires_grad_(True).to(device)

content_weight = 1e4
style_weight = 1e2

# %%
criterion = StyleAndContentLoss(cnn, content_x, style_x, content_layers, style_layers, style_layers_weights=style_layers_weights)
loss = criterion(x)
loss
# Out:
# [INFO] hook registered to Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# [INFO] hook registered to Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
criterion.compute_loss(device)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-84f727f21d63> in <module>
# ----> 1 criterion.compute_loss(device)
#
# <ipython-input-11-437f5bb89026> in compute_loss(self, device)
#      29 #         compute content loss
#      30         for key in self.features['contents'].keys():
# ---> 31             input_features, content_features = self.features['inputs'][key], self.features['contents'][key]
#      32             loss = ContentLoss(content_features)(input_features)
#      33             content_loss += loss
#
# <ipython-input-9-882edbb290cf> in __getitem__(self, key)
#      40
#      41     def __getitem__(self, key):
# ---> 42         return self._state[key]
#      43
#      44     def keys(self):
#
# KeyError: 'inputs'

# %%
criterion(x)

# %%
style_layers = [0, 5, 10, 19, 28]
style_layers_weights = [ 0.75, 0.5, 0.2, 0.2, 0.2]


content_x = loader(content)
style_x = loader(style)
content_weight = 1e4
style_weight = 1e2

cnn = cnn.to(device).eval()

# %%
criterion = StyleAndContentLoss(cnn, style_layers, style_layers_weights)
criterion(content_x, style_x)

# x = content_x.clone().requires_grad_(True).to(device)
x = torch.randn_like(content_x).requires_grad_(True).to(device)
optimizer = optim.Adam([x], 0.01)

# %%
list(cnn.children())
